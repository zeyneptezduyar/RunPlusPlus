# %% [markdown]
# # Fuzzy Run Challenge

# %%
import pandas as pd
import seaborn as sns
from scipy.integrate import simps
from numpy import trapz

# %% [markdown]
# ## Load data

# %%
dfMatt = pd.read_csv("../data/matt.csv")
dfMisha = pd.read_csv("../data/misha.csv")
dfTom = pd.read_csv("../data/tom.csv")

# %% [markdown]
# ## Plot acceleration

# %%
dfMatt.loc[:, ["aX", "aY", "aZ"]].plot()

# %% [markdown]
# ## Plot shor segment

# %%
dfMatt.loc[6000:6200, ["aX", "aY", "aZ"]].plot()

# %%
dfMatt.loc[:, ["gX", "gY", "gZ"]].plot()

# %%
dfMatt.head()
# Out:
#    time        aX        aY        aZ        gX        gY        gZ
# 0     0  0.764648  0.042969  0.650879  0.183105 -3.479004 -2.563477
# 1    10  0.788086  0.041504  0.664062  0.061035 -3.601074 -2.441406
# 2    20  0.771484  0.028320  0.644531  0.122070 -3.540039 -2.563477
# 3    30  0.762207  0.042480  0.646973  0.427246 -3.356934 -2.624512
# 4    40  0.758789  0.040527  0.651855  0.488281 -3.295898 -2.685547

# %%
dfMatt.loc[1900:2200, ["aX", "aY", "aZ"]].plot()

# %%
dfMatt['aX'].plot()

# %%
dfMatt.loc[0:10, ["aX"]].plot()

# %%
dfMatt['time'] = dfMatt['time'].apply(lambda x: x*0.001)

# %%
dfMattaX = dfMatt.drop(['aY', 'aZ', 'gX', 'gY', 'gZ'], axis=1)

# %%
velocity_area = trapz(dfMattaX, dx=0.001)
velocity_area
# Out:
# array([0.00038232, 0.00039904, 0.00039574, ..., 0.07229613, 0.07230016,
#        0.07230711])

# %%
df_velocity = pd.DataFrame(data=velocity_area)
df_velocity.plot()

# %%
df_velocity.loc[0:10, [0]].plot()

# %%
time = dfMattaX["time"]
df_velocity = df_velocity.join(time)

# %%
df_velocity.head()
# Out:
#           0  time
# 0  0.000382  0.00
# 1  0.000399  0.01
# 2  0.000396  0.02
# 3  0.000396  0.03
# 4  0.000399  0.04

# %%
distance_area = trapz(df_velocity, dx=5)
distance_area
# Out:
# array([9.55810547e-04, 2.59976074e-02, 5.09893555e-02, ...,
#        3.60230740e+02, 3.60255750e+02, 3.60280768e+02])

# %%
df_distance = pd.DataFrame(data=distance_area)
df_distance.plot()

# %%
area_last = trapz(df_velocity[0], dx=0.001)
area_last
# Out:
# 0.5265298949804688

# %%
df_distance.loc[2000:2200, [0]].plot()

# %%
df_distance.head()
# Out:
#           0
# 0  0.000956
# 1  0.025998
# 2  0.050989
# 3  0.075990
# 4  0.100998

# %%
dfMattFinal = df_distance
dfMattFinal[1] = df_velocity[0]
dfMattFinal[2] = dfMatt['aX']
dfMattFinal = dfMattFinal.rename(columns={0: "distance", 1: "velocity", 2:"acceleration"})

# %%
dfMattFinal.head()
# Out:
#    distance  velocity  acceleration
# 0  0.000956  0.000382      0.764648
# 1  0.025998  0.000399      0.788086
# 2  0.050989  0.000396      0.771484
# 3  0.075990  0.000396      0.762207
# 4  0.100998  0.000399      0.758789

# %%
dfMattFinal.plot()

# %%
dfMattFinal.head()
# Out:
#    distance  velocity  acceleration
# 0  0.000956  0.000382      0.764648
# 1  0.025998  0.000399      0.788086
# 2  0.050989  0.000396      0.771484
# 3  0.075990  0.000396      0.762207
# 4  0.100998  0.000399      0.758789

# %%
dfMattFinal.loc[2200:2500].plot()
